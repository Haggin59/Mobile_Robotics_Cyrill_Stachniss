# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Mobile_Robotics_Cyrill_Stachniss

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/Mobile_Robotics_Cyrill_Stachniss"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Mobile_Robotics_Cyrill_Stachniss

# %%
# !ls
# Out:
# '3D Coordinates and Representations of Rotations '   gitWork.ipynb

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/Mobile_Robotics_Cyrill_Stachniss/.git/

# %%
# !git remote add origin https://Haggin59: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@github.com/Haggin59/Mobile_Robotics_Cyrill_Stachniss.git

# %%
# !git remote remove origin

# %%
# !git remote -v
# Out:
# origin	https://Haggin59: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@github.com/Haggin59/Mobile_Robotics_Cyrill_Stachniss.git (fetch)
# origin	https://Haggin59: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@github.com/Haggin59/Mobile_Robotics_Cyrill_Stachniss.git (push)

# %%
# !git config --global user.email 'hagginsajeev@gmail.com'

# %%
# !git config --global user.name 'haggin'

# %%
# !git add .

# %%
# !git commit -m "first commit"
# Out:
# [master (root-commit) 21882c8] first commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 3D Coordinates and Representations of Rotations /operations_on_vectors_2D.ipynb
#  create mode 100644 gitWork.ipynb

# %%
# !git log
# Out:
# commit 21882c81afb9ebd8961c893b4d308d8df6da2e8a (HEAD -> master)
# Author: haggin <hagginsajeev@gmail.com>
# Date:   Sun Nov 13 07:56:41 2022 +0000
#
#     first commit

# %%
# !git push origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 19.53 KiB | 2.79 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/Haggin59/Mobile_Robotics_Cyrill_Stachniss.git
#  * [new branch]      master -> master

# %%
# !git pull origin master
# Out:
# From https://github.com/Haggin59/Mobile_Robotics_Cyrill_Stachniss
#  * branch            master     -> FETCH_HEAD
# Updating 21882c8..4375e6e
# Fast-forward
#  README.md | 13 +++++++++++++
#  1 file changed, 13 insertions(+)
#  create mode 100644 README.md
